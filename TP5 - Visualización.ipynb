# %% [markdown]
# # TP4 - Visualización
#
# Seleccionar tres gráficos con mala visualización.
#
# - <a href="https://www.consultantsmind.com/2017/04/10/bad-charts/"> Página 1 </a>
# - <a href="https://badvisualisations.tumblr.com/"> Página 2 </a>
# - <a href="https://flowingdata.com/category/visualization/ugly-visualization/"> Página 3 </a>
#
# Para cada gŕafico:
#
# - Mostrar una imagen del gráfico
# - Explicar por qué es una mala representación
# - Utilizar Matplotlib para representar correctamente los datos

# %% [markdown]
# <img src="https://64.media.tumblr.com/d378eb38c34832c6a0c13536a99f6acc/tumblr_pubelwqiK21xbq2wwo1_500.jpg">

# %% [markdown]
# Este grafico es una mala representacion porque cada porcentaje es independiente del resto, y la suma supera el 100 % total

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (15,7))
x = ["Rahmat Shah","Kusal Perera","Root","Pooran","Du Plessis","Babar", "Warner", "Shakib", "Rohit", "Williamson"]
y = [14.8,18.16,19.07,20.01,21.06,24.51,25.02,28.25,29.05,30.23]
plt.bar(x,y)
plt.xlabel("Players")
plt.ylabel("% of team's runs scored by top scorer")
plt.title("The world cup's big guns")
plt.show();

# %% [markdown]
# <img src="https://64.media.tumblr.com/3b48ff9d930a4f9af3a2da099796d38a/tumblr_psth6k4np51xbq2wwo1_1280.jpg">

# %% [markdown]
# El grafico esta mal representado ya que primero no se entiende bien de que sirve el eje izquierdo y  no sabe de que son esos valores que estan en circulo rojo que estan en circulo rojo

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (15,7))
x = ["Virat Kohli","Kedar Jadhav","Rohit Sharma", "Shikhar Dhawan","Ms Shoni"]
y = [100,62,51.9,34.4,24.77]
plt.scatter(x,y,color='red') 
plt.xlabel("Jugadores de Badminton")
plt.ylabel("Promedio de bateo")
plt.title("Indian Batmen Vs Left-Arm Pace")
# Out:
# Text(0.5, 1.0, 'Indian Batmen Vs Left-Arm Pace')

# %% [markdown]
# <img src="https://flowingdata.com/wp-content/uploads/2009/11/Fox-News-pie-chart-620x465.png">

# %% [markdown]
# El problema que tiene este grafico es que no respeta el 100 %, ademas pareceria que los tres porcentajes tuvieran
# el mismo tamaño

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize = (15,7))

x = ["Back Romney","Back Huckabee","Back Palin"]
y = [60,63,70]
plt.bar(x,y)
plt.xlabel("Candidatos")
plt.ylabel("Porcentajes")
plt.title("2012 Presidecial Run")
# Out:
# Text(0.5, 1.0, '2012 Presidecial Run')
